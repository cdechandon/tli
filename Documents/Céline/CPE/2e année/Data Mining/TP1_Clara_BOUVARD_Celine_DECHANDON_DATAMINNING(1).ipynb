# %%
print('Hello')
# Out:
# Hello

# %%
print("world!")
# Out:
# world!

# %%
import numpy as np
dataset = np.loadtxt("pl.csv", dtype={'names': ('name', 'year'), 'formats': ('U100', 'i4')},
   skiprows=1, delimiter=",")
print(dataset)
# Out:
# [("b'ENIAC coding system'", 1943) ("b'ENIAC Short Code'", 1946)
#  ("b'Von Neumann and Goldstine graphing system'", 1946)
#  ("b'ARC Assembly'", 1947) ("b'Plankalkul'", 1948)
#  ("b'CPC Coding scheme'", 1948) ("b'Curry notation system'", 1948)
#  ("b'Short Code'", 1949) ("b'assembly language'", 1949)
#  ("b'Short Code'", 1950) ("b'G-code'", 1950)
#  ("b'Birkbeck Assembler'", 1950) ("b'Superplan'", 1951) ("b'ALGAE'", 1951)
#  ("b'Intermediate Programming Language'", 1951)
#  ("b'Regional Assembly Language'", 1951)
#  ("b'Boehm unnamed coding system'", 1951) ("b'Klammerausdrucke'", 1951)
#  ("b'OMNIBAC Symbolic Assembler'", 1951) ("b'Stanislaus'", 1951)
#  ("b'Whirlwind assembler'", 1951) ("b'Rochester assembler'", 1951)
#  ("b'Sort Merge Generator'", 1951) ("b'autocode'", 1952)
#  ("b'A-0 System'", 1952) ("b'Editing Generator'", 1952)
#  ("b'COMPOOL'", 1952) ("b'Speedcoding'", 1953) ("b'READ/PRINT'", 1953)
#  ("b'Fortran'", 1954) ("b'ARITH-MATIC'", 1954) ("b'autocode'", 1954)
# ...

# %%
import numpy as np
dataset = np.loadtxt("pl.tsv", dtype={'names': ('name', 'year'), 'formats': ('U100', 'i4')},
   skiprows=1, delimiter="\t")
print(dataset)
# Out:
# [("b'ENIAC coding system'", 1943) ("b'ENIAC Short Code'", 1946)
#  ("b'Von Neumann and Goldstine graphing system'", 1946)
#  ("b'ARC Assembly'", 1947) ("b'Plankalkul'", 1948)
#  ("b'CPC Coding scheme'", 1948) ("b'Curry notation system'", 1948)
#  ("b'Short Code'", 1949) ("b'assembly language'", 1949)
#  ("b'Short Code'", 1950) ("b'Birkbeck Assembler'", 1950)
#  ("b'G-code'", 1950) ("b'Superplan'", 1951) ("b'ALGAE'", 1951)
#  ("b'Intermediate Programming Language'", 1951)
#  ("b'Regional Assembly Language'", 1951)
#  ("b'Boehm unnamed coding system'", 1951) ("b'Klammerausdrucke'", 1951)
#  ("b'OMNIBAC Symbolic Assembler'", 1951) ("b'Stanislaus'", 1951)
#  ("b'Whirlwind assembler'", 1951) ("b'Rochester assembler'", 1951)
#  ("b'Sort Merge Generator'", 1951) ("b'Editing Generator'", 1952)
#  ("b'COMPOOL'", 1952) ("b'autocode'", 1952) ("b'A-0 System'", 1952)
#  ("b'READ/PRINT'", 1953) ("b'Speedcoding'", 1953) ("b'Fortran'", 1954)
# ...

# %%
import numpy as np
dataset = np.loadtxt("pl.tsv", dtype={'names': ('name', 'year'), 'formats': ('U100', 'i4')},
   skiprows=1, delimiter="\t")
print(dataset)
# Out:
# [("b'ENIAC coding system'", 1943) ("b'ENIAC Short Code'", 1946)
#  ("b'Von Neumann and Goldstine graphing system'", 1946)
#  ("b'ARC Assembly'", 1947) ("b'Plankalkul'", 1948)
#  ("b'CPC Coding scheme'", 1948) ("b'Curry notation system'", 1948)
#  ("b'Short Code'", 1949) ("b'assembly language'", 1949)
#  ("b'Short Code'", 1950) ("b'Birkbeck Assembler'", 1950)
#  ("b'G-code'", 1950) ("b'Superplan'", 1951) ("b'ALGAE'", 1951)
#  ("b'Intermediate Programming Language'", 1951)
#  ("b'Regional Assembly Language'", 1951)
#  ("b'Boehm unnamed coding system'", 1951) ("b'Klammerausdrucke'", 1951)
#  ("b'OMNIBAC Symbolic Assembler'", 1951) ("b'Stanislaus'", 1951)
#  ("b'Whirlwind assembler'", 1951) ("b'Rochester assembler'", 1951)
#  ("b'Sort Merge Generator'", 1951) ("b'Editing Generator'", 1952)
#  ("b'COMPOOL'", 1952) ("b'autocode'", 1952) ("b'A-0 System'", 1952)
#  ("b'READ/PRINT'", 1953) ("b'Speedcoding'", 1953) ("b'Fortran'", 1954)
# ...

# %%
import numpy as np
dataset = np.loadtxt("pl.tsv", dtype={'names': ('name', 'year'), 'formats': ('U100', 'i4')},
   skiprows=1, delimiter="\t")
print(dataset)
# Out:
# [("b'ENIAC coding system'", 1943) ("b'ENIAC Short Code'", 1946)
#  ("b'Von Neumann and Goldstine graphing system'", 1946)
#  ("b'ARC Assembly'", 1947) ("b'Plankalkul'", 1948)
#  ("b'CPC Coding scheme'", 1948) ("b'Curry notation system'", 1948)
#  ("b'Short Code'", 1949) ("b'assembly language'", 1949)
#  ("b'Short Code'", 1950) ("b'Birkbeck Assembler'", 1950)
#  ("b'G-code'", 1950) ("b'Superplan'", 1951) ("b'ALGAE'", 1951)
#  ("b'Intermediate Programming Language'", 1951)
#  ("b'Regional Assembly Language'", 1951)
#  ("b'Boehm unnamed coding system'", 1951) ("b'Klammerausdrucke'", 1951)
#  ("b'OMNIBAC Symbolic Assembler'", 1951) ("b'Stanislaus'", 1951)
#  ("b'Whirlwind assembler'", 1951) ("b'Rochester assembler'", 1951)
#  ("b'Sort Merge Generator'", 1951) ("b'Editing Generator'", 1952)
#  ("b'COMPOOL'", 1952) ("b'autocode'", 1952) ("b'A-0 System'", 1952)
#  ("b'READ/PRINT'", 1953) ("b'Speedcoding'", 1953) ("b'Fortran'", 1954)
# ...

# %%
from pandas.io.json import json_normalize
import pandas as pd
import json

data = json.load(open('pl.json'))
dataframe = json_normalize(data)
print(dataframe)
# Out:
#                                         languageLabel  year
# 0                                 ENIAC coding system  1943
# 1                                    ENIAC Short Code  1946
# 2           Von Neumann and Goldstine graphing system  1946
# 3                                        ARC Assembly  1947
# 4                                          Plankalkul  1948
# 5                                   CPC Coding scheme  1948
# 6                               Curry notation system  1948
# 7                                          Short Code  1949
# 8                                   assembly language  1949
# 9                                          Short Code  1950
# 10                                 Birkbeck Assembler  1950
# 11                                             G-code  1950
# 12                                          Superplan  1951
# 13                                              ALGAE  1951
# 14                  Intermediate Programming Language  1951
# ...

# %%
from pandas.io.json import json_normalize
import pandas as pd
import json

data = json.load(open('query.json'))
dataframe = json_normalize(data)
print(dataframe)
# Out:
#                               instance_of       instance_ofLabel
# 0    http://www.wikidata.org/entity/Q2366            AngelScript
# 1    http://www.wikidata.org/entity/Q2378           Visual Basic
# 2    http://www.wikidata.org/entity/Q2407                    C++
# 3    http://www.wikidata.org/entity/Q5288  Tool Command Language
# 4    http://www.wikidata.org/entity/Q5301                    TeX
# 5   http://www.wikidata.org/entity/Q13743    Visual Basic Script
# 6   http://www.wikidata.org/entity/Q15777                      C
# 7   http://www.wikidata.org/entity/Q16340                  XPath
# 8   http://www.wikidata.org/entity/Q20479                   Agda
# 9   http://www.wikidata.org/entity/Q28865                 Python
# 10  http://www.wikidata.org/entity/Q32110                   XSLT
# 11  http://www.wikidata.org/entity/Q34280             Plankalkül
# 12  http://www.wikidata.org/entity/Q37227                     Go
# ...

# %%
from pandas.io.json import json_normalize
import pandas as pd
import json

data = json.load(open('query.json'))
dataframe = json_normalize(data)
print(dataframe)
# Out:
#                               instance_of       instance_ofLabel
# 0    http://www.wikidata.org/entity/Q2366            AngelScript
# 1    http://www.wikidata.org/entity/Q2378           Visual Basic
# 2    http://www.wikidata.org/entity/Q2407                    C++
# 3    http://www.wikidata.org/entity/Q5288  Tool Command Language
# 4    http://www.wikidata.org/entity/Q5301                    TeX
# 5   http://www.wikidata.org/entity/Q13743    Visual Basic Script
# 6   http://www.wikidata.org/entity/Q15777                      C
# 7   http://www.wikidata.org/entity/Q16340                  XPath
# 8   http://www.wikidata.org/entity/Q20479                   Agda
# 9   http://www.wikidata.org/entity/Q28865                 Python
# 10  http://www.wikidata.org/entity/Q32110                   XSLT
# 11  http://www.wikidata.org/entity/Q34280             Plankalkül
# 12  http://www.wikidata.org/entity/Q37227                     Go
# ...

# %%
from pandas.io.json import json_normalize
import pandas as pd
import json

data = json.load(open('query.json'))
dataframe = json_normalize(data)
print(dataframe)
# Out:
#                               instance_of       instance_ofLabel
# 0    http://www.wikidata.org/entity/Q2366            AngelScript
# 1    http://www.wikidata.org/entity/Q2378           Visual Basic
# 2    http://www.wikidata.org/entity/Q2407                    C++
# 3    http://www.wikidata.org/entity/Q5288  Tool Command Language
# 4    http://www.wikidata.org/entity/Q5301                    TeX
# 5   http://www.wikidata.org/entity/Q13743    Visual Basic Script
# 6   http://www.wikidata.org/entity/Q15777                      C
# 7   http://www.wikidata.org/entity/Q16340                  XPath
# 8   http://www.wikidata.org/entity/Q20479                   Agda
# 9   http://www.wikidata.org/entity/Q28865                 Python
# 10  http://www.wikidata.org/entity/Q32110                   XSLT
# 11  http://www.wikidata.org/entity/Q34280             Plankalkül
# 12  http://www.wikidata.org/entity/Q37227                     Go
# ...

# %%
from pandas.io.json import json_normalize
import pandas as pd
import json

data = json.load(open('pl.json'))
dataframe = json_normalize(data)
grouped = dataframe.groupby('year').count()
print(grouped)
# Out:
#       languageLabel
# year
# 1943              1
# 1946              2
# 1947              1
# 1948              3
# 1949              2
# 1950              3
# 1951             11
# 1952              4
# 1953              2
# 1954              6
# 1955              7
# 1956              2
# 1957              4
# 1958              5
# 1959              6
# 1960              4
# 1961              1
# 1962              5
# 1963              2
# 1964              9
# 1965              3
# 1966              9
# 1967              7
# 1968              1

# %%
from pandas.io.json import json_normalize
import pandas as pd
import json

data = json.load(open('pl.json'))
dataframe = json_normalize(data)
grouped = dataframe.groupby('year').count()
print(grouped)
# Out:
#       languageLabel
# year
# 1943              1
# 1946              2
# 1947              1
# 1948              3
# 1949              2
# 1950              3
# 1951             11
# 1952              4
# 1953              2
# 1954              6
# 1955              7
# 1956              2
# 1957              4
# 1958              5
# 1959              6
# 1960              4
# 1961              1
# 1962              5
# 1963              2
# 1964              9
# 1965              3
# 1966              9
# 1967              7
# 1968              1

# %%
from pandas.io.json import json_normalize
import pandas as pd
import json

data = json.load(open('pl.json'))
dataframe = json_normalize(data)
grouped = dataframe.groupby('year').count()
print(grouped)
# Out:
#       languageLabel
# year
# 1943              1
# 1946              2
# 1947              1
# 1948              3
# 1949              2
# 1950              3
# 1951             11
# 1952              4
# 1953              2
# 1954              6
# 1955              7
# 1956              2
# 1957              4
# 1958              5
# 1959              6
# 1960              4
# 1961              1
# 1962              5
# 1963              2
# 1964              9
# 1965              3
# 1966              9
# 1967              7
# 1968              1

# %%
from pandas.io.json import json_normalize
import pandas as pd
import json

data = json.load(open('pl.json'))
dataframe = json_normalize(data)
grouped = dataframe.groupby('year').count()
print(grouped)
# Out:
#       languageLabel
# year
# 1943              1
# 1946              2
# 1947              1
# 1948              3
# 1949              2
# 1950              3
# 1951             11
# 1952              4
# 1953              2
# 1954              6
# 1955              7
# 1956              2
# 1957              4
# 1958              5
# 1959              6
# 1960              4
# 1961              1
# 1962              5
# 1963              2
# 1964              9
# 1965              3
# 1966              9
# 1967              7
# 1968              1

# %%
from pandas.io.json import json_normalize
import pandas as pd
import json

data = json.load(open('pl.json'))
dataframe = json_normalize(data)
grouped = dataframe.groupby('year').count()
print(grouped)
# Out:
#       languageLabel
# year
# 1943              1
# 1946              2
# 1947              1
# 1948              3
# 1949              2
# 1950              3
# 1951             11
# 1952              4
# 1953              2
# 1954              6
# 1955              7
# 1956              2
# 1957              4
# 1958              5
# 1959              6
# 1960              4
# 1961              1
# 1962              5
# 1963              2
# 1964              9
# 1965              3
# 1966              9
# 1967              7
# 1968              1

# %%
from pandas.io.json import json_normalize
import pandas as pd
import json

data = json.load(open('pl.json'))
dataframe = json_normalize(data)
grouped = dataframe.groupby('year').count()
print(grouped)
# Out:
#       languageLabel
# year
# 1943              1
# 1946              2
# 1947              1
# 1948              3
# 1949              2
# 1950              3
# 1951             11
# 1952              4
# 1953              2
# 1954              6
# 1955              7
# 1956              2
# 1957              4
# 1958              5
# 1959              6
# 1960              4
# 1961              1
# 1962              5
# 1963              2
# 1964              9
# 1965              3
# 1966              9
# 1967              7
# 1968              1

# %%
from pandas.io.json import json_normalize
import pandas as pd
import json

data = json.load(open('pl.json'))
dataframe = json_normalize(data)
grouped = dataframe.groupby('year').count()
print(grouped)
# Out:
#       languageLabel
# year
# 1943              1
# 1946              2
# 1947              1
# 1948              3
# 1949              2
# 1950              3
# 1951             11
# 1952              4
# 1953              2
# 1954              6
# 1955              7
# 1956              2
# 1957              4
# 1958              5
# 1959              6
# 1960              4
# 1961              1
# 1962              5
# 1963              2
# 1964              9
# 1965              3
# 1966              9
# 1967              7
# 1968              1

# %%
from pandas.io.json import json_normalize
import pandas as pd
import json

data = json.load(open('pl.json'))
dataframe = json_normalize(data)
grouped = dataframe.groupby('year').count()
print(grouped)
# Out:
#       languageLabel
# year
# 1943              1
# 1946              2
# 1947              1
# 1948              3
# 1949              2
# 1950              3
# 1951             11
# 1952              4
# 1953              2
# 1954              6
# 1955              7
# 1956              2
# 1957              4
# 1958              5
# 1959              6
# 1960              4
# 1961              1
# 1962              5
# 1963              2
# 1964              9
# 1965              3
# 1966              9
# 1967              7
# 1968              1

# %%
from pandas.io.json import json_normalize
import pandas as pd
import json

data = json.load(open('pl.json'))
dataframe = json_normalize(data)
grouped = dataframe.groupby('year').count()
print(grouped)
# Out:
#       languageLabel
# year
# 1943              1
# 1946              2
# 1947              1
# 1948              3
# 1949              2
# 1950              3
# 1951             11
# 1952              4
# 1953              2
# 1954              6
# 1955              7
# 1956              2
# 1957              4
# 1958              5
# 1959              6
# 1960              4
# 1961              1
# 1962              5
# 1963              2
# 1964              9
# 1965              3
# 1966              9
# 1967              7
# 1968              1

# %%
from pandas.io.json import json_normalize
import pandas as pd
import json

data = json.load(open('pl.json'))
dataframe = json_normalize(data)
grouped = dataframe.groupby('year').agg(['count'])
print(grouped)
# Out:
#      languageLabel
#              count
# year
# 1943             1
# 1946             2
# 1947             1
# 1948             3
# 1949             2
# 1950             3
# 1951            11
# 1952             4
# 1953             2
# 1954             6
# 1955             7
# 1956             2
# 1957             4
# 1958             5
# 1959             6
# 1960             4
# 1961             1
# 1962             5
# 1963             2
# 1964             9
# 1965             3
# 1966             9
# 1967             7
# 1968             1

# %%
from pandas.io.json import json_normalize
import pandas as pd
import json

jsondata = json.load(open('plparadigm.json'))
array = []

for data in jsondata:
  array.append([data['year'], data['languageLabel'], data['paradigmLabel']])
dataframe = pd.DataFrame(array, columns=['year', 'languageLabel', 'paradigmLabel'])
dataframe = dataframe.astype(dtype= {"year" : "int64", "languageLabel" : "<U200", "paradigmLabel" : "<U200"})

grouped = dataframe.groupby(['year', 'paradigmLabel']).agg(['count'])
print(grouped)
# Out:
#                                             languageLabel
#                                                     count
# year paradigmLabel
# 1948 procedural programming                             1
# 1949 non-structured programming                         1
#      procedural programming                             1
# 1950 procedural programming                             1
# 1953 procedural programming                             1
#      structured programming                             1
# 1954 array programming                                  1
#      generic programming                                1
#      imperative programming                             2
#      object-oriented programming                        1
#      procedural programming                             1
#      structured programming                             1
# 1955 imperative programming                             1
#      procedural programming                             1
# ...

# %%
from pandas.io.json import json_normalize
import pandas as pd
import json

jsondata = json.load(open('plparadigm.json'))
array = []

for data in jsondata:
  array.append([data['year'], data['languageLabel'], data['paradigmLabel']])
dataframe = pd.DataFrame(array, columns=['year', 'languageLabel', 'paradigmLabel'])
dataframe = dataframe.astype(dtype= {"year" : "int64", "languageLabel" : "<U200", "paradigmLabel" : "<U200"})

grouped = dataframe.groupby(['year', 'paradigmLabel']).agg(['count'])
print(grouped)
# Out:
#                                             languageLabel
#                                                     count
# year paradigmLabel
# 1948 procedural programming                             1
# 1949 non-structured programming                         1
#      procedural programming                             1
# 1950 procedural programming                             1
# 1953 procedural programming                             1
#      structured programming                             1
# 1954 array programming                                  1
#      generic programming                                1
#      imperative programming                             2
#      object-oriented programming                        1
#      procedural programming                             1
#      structured programming                             1
# 1955 imperative programming                             1
#      procedural programming                             1
# ...

# %%
from pandas.io.json import json_normalize
import pandas as pd
import json

jsondata = json.load(open('plparadigm.json'))
array = []

for data in jsondata:
  array.append([data['year'], data['languageLabel'], data['paradigmLabel']])
dataframe = pd.DataFrame(array, columns=['year', 'languageLabel', 'paradigmLabel'])
dataframe = dataframe.astype(dtype= {"year" : "int64", "languageLabel" : "<U200", "paradigmLabel" : "<U200"})

grouped = dataframe.groupby(['year', 'paradigmLabel']).agg(['count'])
print(grouped)
# Out:
#                                             languageLabel
#                                                     count
# year paradigmLabel
# 1948 procedural programming                             1
# 1949 non-structured programming                         1
#      procedural programming                             1
# 1950 procedural programming                             1
# 1953 procedural programming                             1
#      structured programming                             1
# 1954 array programming                                  1
#      generic programming                                1
#      imperative programming                             2
#      object-oriented programming                        1
#      procedural programming                             1
#      structured programming                             1
# 1955 imperative programming                             1
#      procedural programming                             1
# ...

# %%
from pandas.io.json import json_normalize
import pandas as pd
import json

jsondata = json.load(open('plparadigm.json'))
array = []

for data in jsondata:
  array.append([data['year'], data['languageLabel'], data['paradigmLabel']])
dataframe = pd.DataFrame(array, columns=['year', 'languageLabel', 'paradigmLabel'])
dataframe = dataframe.astype(dtype= {"year" : "int64", "languageLabel" : "<U200", "paradigmLabel" : "<U200"})

grouped = dataframe.groupby(['year', 'paradigmLabel']).agg(['count'])
print(grouped)
# Out:
#                                             languageLabel
#                                                     count
# year paradigmLabel
# 1948 procedural programming                             1
# 1949 non-structured programming                         1
#      procedural programming                             1
# 1950 procedural programming                             1
# 1953 procedural programming                             1
#      structured programming                             1
# 1954 array programming                                  1
#      generic programming                                1
#      imperative programming                             2
#      object-oriented programming                        1
#      procedural programming                             1
#      structured programming                             1
# 1955 imperative programming                             1
#      procedural programming                             1
# ...

# %%
from pandas.io.json import json_normalize
import pandas as pd
import json

jsondata = json.load(open('plparadigm.json'))
array = []

for data in jsondata:
  array.append([data['year'], data['languageLabel'], data['paradigmLabel']])
dataframe = pd.DataFrame(array, columns=['year', 'languageLabel', 'paradigmLabel'])
dataframe = dataframe.astype(dtype= {"year" : "int64", "languageLabel" : "<U200", "paradigmLabel" : "<U200"})

grouped = dataframe.groupby(['paradigmLabel', 'year']).agg(['count'])
print(grouped)
# Out:
#                                             languageLabel
#                                                     count
# paradigmLabel                          year
# array programming                      1954             1
#                                        1957             1
#                                        1962             1
#                                        1966             1
# assembly language                      1956             1
# functional programming                 1958             1
#                                        1959             1
#                                        1962             1
#                                        1966             2
#                                        1967             1
#                                        1968             1
#                                        1971             1
# generic programming                    1954             1
# ...

# %%
from pandas.io.json import json_normalize
import pandas as pd
import json

jsondata = json.load(open('countrie.json'))
array = []

for data in jsondata:
    array.append([data['year'], data['population'], data['countryLabel']])
dataframe = pd.DataFrame(array, columns=['year', 'population', 'countryLabel'])
dataframe = dataframe.astype(dtype= {"year" : "int64", "population" : "<U200", "countryLabel" : "<U200"})

grouped = dataframe.sort_values(['countryLabel', 'year'])
print(grouped)
# Out:
#      year population countryLabel
# 0    1960    8774440  Afghanistan
# 1    1961    8953544  Afghanistan
# 2    1962    9141783  Afghanistan
# 3    1963    9339507  Afghanistan
# 4    1964    9547131  Afghanistan
# 5    1965    9765015  Afghanistan
# 6    1966    9990125  Afghanistan
# 7    1967   10221902  Afghanistan
# 8    1968   10465770  Afghanistan
# 9    1969   10729191  Afghanistan
# 10   1970   11015621  Afghanistan
# 11   1971   11323446  Afghanistan
# 12   1972   11644377  Afghanistan
# 13   1973   11966352  Afghanistan
# 14   1974   12273589  Afghanistan
# 15   1975   12551790  Afghanistan
# 16   1976   12806810  Afghanistan
# 17   1977   13034460  Afghanistan
# 18   1978   13199597  Afghanistan
# 19   1979   15500000  Afghanistan
# 20   1979   13257128  Afghanistan
# 21   1980   13180431  Afghanistan
# 22   1981   12963788  Afghanistan
# 23   1982   12634494  Afghanistan
# 24   1983   12241928  Afghanistan
# 25   1984   11854205  Afghanistan
# ...

# %%
from pandas.io.json import json_normalize
import pandas as pd
import json

jsondata = json.load(open('countrie.json'))
array = []

for data in jsondata:
    array.append([data['year'], data['population'], data['countryLabel']])
dataframe = pd.DataFrame(array, columns=['year', 'population', 'countryLabel'])
dataframe = dataframe.astype(dtype= {"year" : "int64", "population" : "<U200", "countryLabel" : "<U200"})

grouped = dataframe.sort_values(['countryLabel', 'year'])
print(grouped)
# Out:
#      year population countryLabel
# 0    1960    8774440  Afghanistan
# 1    1961    8953544  Afghanistan
# 2    1962    9141783  Afghanistan
# 3    1963    9339507  Afghanistan
# 4    1964    9547131  Afghanistan
# 5    1965    9765015  Afghanistan
# 6    1966    9990125  Afghanistan
# 7    1967   10221902  Afghanistan
# 8    1968   10465770  Afghanistan
# 9    1969   10729191  Afghanistan
# 10   1970   11015621  Afghanistan
# 11   1971   11323446  Afghanistan
# 12   1972   11644377  Afghanistan
# 13   1973   11966352  Afghanistan
# 14   1974   12273589  Afghanistan
# 15   1975   12551790  Afghanistan
# 16   1976   12806810  Afghanistan
# 17   1977   13034460  Afghanistan
# 18   1978   13199597  Afghanistan
# 19   1979   15500000  Afghanistan
# 20   1979   13257128  Afghanistan
# 21   1980   13180431  Afghanistan
# 22   1981   12963788  Afghanistan
# 23   1982   12634494  Afghanistan
# 24   1983   12241928  Afghanistan
# 25   1984   11854205  Afghanistan
# ...

# %%
from pandas.io.json import json_normalize
import pandas as pd
import json

jsondata = json.load(open('countrie.json'))
array = []

for data in jsondata:
    array.append([data['year'], data['population'], data['countryLabel']])
dataframe = pd.DataFrame(array, columns=['year', 'population', 'countryLabel'])
dataframe = dataframe.astype(dtype= {"year" : "int64", "population" : "<U200", "countryLabel" : "<U200"})

grouped = dataframe.sort_values(['countryLabel', 'year'])
print(grouped)
# Out:
#      year population countryLabel
# 0    1960    8774440  Afghanistan
# 1    1961    8953544  Afghanistan
# 2    1962    9141783  Afghanistan
# 3    1963    9339507  Afghanistan
# 4    1964    9547131  Afghanistan
# 5    1965    9765015  Afghanistan
# 6    1966    9990125  Afghanistan
# 7    1967   10221902  Afghanistan
# 8    1968   10465770  Afghanistan
# 9    1969   10729191  Afghanistan
# 10   1970   11015621  Afghanistan
# 11   1971   11323446  Afghanistan
# 12   1972   11644377  Afghanistan
# 13   1973   11966352  Afghanistan
# 14   1974   12273589  Afghanistan
# 15   1975   12551790  Afghanistan
# 16   1976   12806810  Afghanistan
# 17   1977   13034460  Afghanistan
# 18   1978   13199597  Afghanistan
# 19   1979   15500000  Afghanistan
# 20   1979   13257128  Afghanistan
# 21   1980   13180431  Afghanistan
# 22   1981   12963788  Afghanistan
# 23   1982   12634494  Afghanistan
# 24   1983   12241928  Afghanistan
# 25   1984   11854205  Afghanistan
# ...

# %%
from pandas.io.json import json_normalize
import pandas as pd
import json

jsondata = json.load(open('countrie.json'))
array = []

for data in jsondata:
    array.append([data['year'], data['population'], data['countryLabel']])
dataframe = pd.DataFrame(array, columns=['year', 'population', 'countryLabel'])
dataframe = dataframe.astype(dtype= {"year" : "int64", "population" : "<U200", "countryLabel" : "<U200"})

grouped = dataframe.sort_values(['countryLabel', 'year'])
print(grouped)
# Out:
#      year population countryLabel
# 0    1960    8774440  Afghanistan
# 1    1961    8953544  Afghanistan
# 2    1962    9141783  Afghanistan
# 3    1963    9339507  Afghanistan
# 4    1964    9547131  Afghanistan
# 5    1965    9765015  Afghanistan
# 6    1966    9990125  Afghanistan
# 7    1967   10221902  Afghanistan
# 8    1968   10465770  Afghanistan
# 9    1969   10729191  Afghanistan
# 10   1970   11015621  Afghanistan
# 11   1971   11323446  Afghanistan
# 12   1972   11644377  Afghanistan
# 13   1973   11966352  Afghanistan
# 14   1974   12273589  Afghanistan
# 15   1975   12551790  Afghanistan
# 16   1976   12806810  Afghanistan
# 17   1977   13034460  Afghanistan
# 18   1978   13199597  Afghanistan
# 19   1979   15500000  Afghanistan
# 20   1979   13257128  Afghanistan
# 21   1980   13180431  Afghanistan
# 22   1981   12963788  Afghanistan
# 23   1982   12634494  Afghanistan
# 24   1983   12241928  Afghanistan
# 25   1984   11854205  Afghanistan
# ...

# %%
from pandas.io.json import json_normalize
import pandas as pd
import json

jsondata = json.load(open('countrie.json'))
array = []

for data in jsondata:
    array.append([data['year'], data['population'], data['countryLabel']])
dataframe = pd.DataFrame(array, columns=['year', 'population', 'countryLabel'])
dataframe = dataframe.astype(dtype= {"year" : "int64", "population" : "<U200", "countryLabel" : "<U200"})

grouped = dataframe.sort_values(['countryLabel', 'year'])
print(grouped)
# Out:
#      year population countryLabel
# 0    1960    8774440  Afghanistan
# 1    1961    8953544  Afghanistan
# 2    1962    9141783  Afghanistan
# 3    1963    9339507  Afghanistan
# 4    1964    9547131  Afghanistan
# 5    1965    9765015  Afghanistan
# 6    1966    9990125  Afghanistan
# 7    1967   10221902  Afghanistan
# 8    1968   10465770  Afghanistan
# 9    1969   10729191  Afghanistan
# 10   1970   11015621  Afghanistan
# 11   1971   11323446  Afghanistan
# 12   1972   11644377  Afghanistan
# 13   1973   11966352  Afghanistan
# 14   1974   12273589  Afghanistan
# 15   1975   12551790  Afghanistan
# 16   1976   12806810  Afghanistan
# 17   1977   13034460  Afghanistan
# 18   1978   13199597  Afghanistan
# 19   1979   15500000  Afghanistan
# 20   1979   13257128  Afghanistan
# 21   1980   13180431  Afghanistan
# 22   1981   12963788  Afghanistan
# 23   1982   12634494  Afghanistan
# 24   1983   12241928  Afghanistan
# 25   1984   11854205  Afghanistan
# ...

# %%
from pandas.io.json import json_normalize
import pandas as pd
import json

jsondata = json.load(open('countrie.json'))
array = []

for data in jsondata:
    array.append([data['year'], data['population'], data['countryLabel']])
dataframe = pd.DataFrame(array, columns=['year', 'population', 'countryLabel'])
dataframe = dataframe.astype(dtype= {"year" : "int64", "population" : "<U200", "countryLabel" : "<U200"})

grouped = dataframe.sort_values(['countryLabel', 'year'])
print(grouped)
# Out:
#      year population countryLabel
# 0    1960    8774440  Afghanistan
# 1    1961    8953544  Afghanistan
# 2    1962    9141783  Afghanistan
# 3    1963    9339507  Afghanistan
# 4    1964    9547131  Afghanistan
# 5    1965    9765015  Afghanistan
# 6    1966    9990125  Afghanistan
# 7    1967   10221902  Afghanistan
# 8    1968   10465770  Afghanistan
# 9    1969   10729191  Afghanistan
# 10   1970   11015621  Afghanistan
# 11   1971   11323446  Afghanistan
# 12   1972   11644377  Afghanistan
# 13   1973   11966352  Afghanistan
# 14   1974   12273589  Afghanistan
# 15   1975   12551790  Afghanistan
# 16   1976   12806810  Afghanistan
# 17   1977   13034460  Afghanistan
# 18   1978   13199597  Afghanistan
# 19   1979   15500000  Afghanistan
# 20   1979   13257128  Afghanistan
# 21   1980   13180431  Afghanistan
# 22   1981   12963788  Afghanistan
# 23   1982   12634494  Afghanistan
# 24   1983   12241928  Afghanistan
# 25   1984   11854205  Afghanistan
# ...

# %%
from pandas.io.json import json_normalize
import pandas as pd
import json

jsondata = json.load(open('countrie.json'))
array = []

for data in jsondata:
    array.append([data['year'], data['population'], data['countryLabel']])
dataframe = pd.DataFrame(array, columns=['year', 'population', 'countryLabel'])
dataframe = dataframe.astype(dtype= {"year" : "int64", "population" : "<U200", "countryLabel" : "<U200"})

grouped = dataframe.sort_values(['countryLabel', 'year'])
print(grouped)
# Out:
#      year population countryLabel
# 0    1960    8774440  Afghanistan
# 1    1961    8953544  Afghanistan
# 2    1962    9141783  Afghanistan
# 3    1963    9339507  Afghanistan
# 4    1964    9547131  Afghanistan
# 5    1965    9765015  Afghanistan
# 6    1966    9990125  Afghanistan
# 7    1967   10221902  Afghanistan
# 8    1968   10465770  Afghanistan
# 9    1969   10729191  Afghanistan
# 10   1970   11015621  Afghanistan
# 11   1971   11323446  Afghanistan
# 12   1972   11644377  Afghanistan
# 13   1973   11966352  Afghanistan
# 14   1974   12273589  Afghanistan
# 15   1975   12551790  Afghanistan
# 16   1976   12806810  Afghanistan
# 17   1977   13034460  Afghanistan
# 18   1978   13199597  Afghanistan
# 19   1979   15500000  Afghanistan
# 20   1979   13257128  Afghanistan
# 21   1980   13180431  Afghanistan
# 22   1981   12963788  Afghanistan
# 23   1982   12634494  Afghanistan
# 24   1983   12241928  Afghanistan
# 25   1984   11854205  Afghanistan
# ...

# %%
from pandas.io.json import json_normalize
import pandas as pd
import json

jsondata = json.load(open('countrie.json'))
array = []

for data in jsondata:
    array.append([data['year'], data['population'], data['countryLabel']])
dataframe = pd.DataFrame(array, columns=['year', 'population', 'countryLabel'])
dataframe = dataframe.astype(dtype= {"year" : "int64", "population" : "<U200", "countryLabel" : "<U200"})

grouped = dataframe.sort_values(['year', 'population'])
print(grouped)
# Out:
#      year population         countryLabel
# 330  1895    3954911            Argentina
# 166  1910       5231              Andorra
# 331  1910    7091822            Argentina
# 111  1960   11277757              Algeria
# 167  1960      13414              Andorra
# 56   1960    1608800              Albania
# 558  1960     162501              Bahrain
# 387  1960    1867396              Armenia
# 332  1960   20623998            Argentina
# 905  1960     224155               Bhutan
# 666  1960     230858             Barbados
# 851  1960    2431620                Benin
# 959  1960    3353125              Bolivia
# 504  1960    3897889           Azerbaijan
# 612  1960   49537147           Bangladesh
# 222  1960    4965988               Angola
# 276  1960      54681  Antigua and Barbuda
# 449  1960    7047539              Austria
# 0    1960    8774440          Afghanistan
# 725  1960    9153489              Belgium
# 793  1960      92068               Belize
# ...

# %%
from pandas.io.json import json_normalize
import pandas as pd
import json

jsondata = json.load(open('countrie.json'))
array = []

for data in jsondata:
    array.append([data['year'], data['population'], data['countryLabel']])
dataframe = pd.DataFrame(array, columns=['year', 'population', 'countryLabel'])
dataframe = dataframe.astype(dtype= {"year" : "int64", "population" : "<U200", "countryLabel" : "<U200"})

grouped = dataframe.groupby(['countryLabel','year']).agg(['last'])

print(grouped)
# Out:
#                   population
#                         last
# countryLabel year
# Afghanistan  1960    8774440
#              1961    8953544
#              1962    9141783
#              1963    9339507
#              1964    9547131
#              1965    9765015
#              1966    9990125
#              1967   10221902
#              1968   10465770
#              1969   10729191
#              1970   11015621
#              1971   11323446
#              1972   11644377
#              1973   11966352
#              1974   12273589
#              1975   12551790
#              1976   12806810
#              1977   13034460
#              1978   13199597
#              1979   13257128
#              1980   13180431
#              1981   12963788
#              1982   12634494
#              1983   12241928
#              1984   11854205
#              1985   11528977
#              1986   11262439
#              1987   11063107
#              1988   11013345
# ...

# %%
from pandas.io.json import json_normalize
import pandas as pd
import json

jsondata = json.load(open('countrie.json'))
array = []

for data in jsondata:
    array.append([data['year'], data['population'], data['countryLabel']])
dataframe = pd.DataFrame(array, columns=['year', 'population', 'countryLabel'])
dataframe = dataframe.astype(dtype= {"year" : "int64", "population" : "<U200", "countryLabel" : "<U200"})

grouped = dataframe.groupby(['countryLabel','year']).agg(['last'])

print(grouped)
# Out:
#                   population
#                         last
# countryLabel year
# Afghanistan  1960    8774440
#              1961    8953544
#              1962    9141783
#              1963    9339507
#              1964    9547131
#              1965    9765015
#              1966    9990125
#              1967   10221902
#              1968   10465770
#              1969   10729191
#              1970   11015621
#              1971   11323446
#              1972   11644377
#              1973   11966352
#              1974   12273589
#              1975   12551790
#              1976   12806810
#              1977   13034460
#              1978   13199597
#              1979   13257128
#              1980   13180431
#              1981   12963788
#              1982   12634494
#              1983   12241928
#              1984   11854205
#              1985   11528977
#              1986   11262439
#              1987   11063107
#              1988   11013345
# ...

# %%
from pandas.io.json import json_normalize
import pandas as pd
import json

jsondata = json.load(open('countrie.json'))
array = []

for data in jsondata:
    array.append([data['year'], data['population'], data['countryLabel']])
dataframe = pd.DataFrame(array, columns=['year', 'population', 'countryLabel'])
dataframe = dataframe.astype(dtype= {"year" : "int64", "population" : "<U200", "countryLabel" : "<U200"})

grouped = dataframe.groupby(['countryLabel','year']).agg(['last'])

print(grouped)
# Out:
#                   population
#                         last
# countryLabel year
# Afghanistan  1960    8774440
#              1961    8953544
#              1962    9141783
#              1963    9339507
#              1964    9547131
#              1965    9765015
#              1966    9990125
#              1967   10221902
#              1968   10465770
#              1969   10729191
#              1970   11015621
#              1971   11323446
#              1972   11644377
#              1973   11966352
#              1974   12273589
#              1975   12551790
#              1976   12806810
#              1977   13034460
#              1978   13199597
#              1979   13257128
#              1980   13180431
#              1981   12963788
#              1982   12634494
#              1983   12241928
#              1984   11854205
#              1985   11528977
#              1986   11262439
#              1987   11063107
#              1988   11013345
# ...

# %%
from pandas.io.json import json_normalize
import pandas as pd
import json

jsondata = json.load(open('countrie.json'))
array = []

for data in jsondata:
    array.append([data['year'], data['population'], data['countryLabel']])
dataframe = pd.DataFrame(array, columns=['year', 'population', 'countryLabel'])
dataframe = dataframe.astype(dtype= {"year" : "int64", "population" : "<U200", "countryLabel" : "<U200"})

grouped = dataframe.groupby(['countryLabel','year']).agg(['last'])

print(grouped)
# Out:
#                   population
#                         last
# countryLabel year
# Afghanistan  1960    8774440
#              1961    8953544
#              1962    9141783
#              1963    9339507
#              1964    9547131
#              1965    9765015
#              1966    9990125
#              1967   10221902
#              1968   10465770
#              1969   10729191
#              1970   11015621
#              1971   11323446
#              1972   11644377
#              1973   11966352
#              1974   12273589
#              1975   12551790
#              1976   12806810
#              1977   13034460
#              1978   13199597
#              1979   13257128
#              1980   13180431
#              1981   12963788
#              1982   12634494
#              1983   12241928
#              1984   11854205
#              1985   11528977
#              1986   11262439
#              1987   11063107
#              1988   11013345
# ...

# %%
from pandas.io.json import json_normalize
import pandas as pd
import json

jsondata = json.load(open('countrie.json'))
array = []

for data in jsondata:
    array.append([data['year'], data['population'], data['countryLabel']])
dataframe = pd.DataFrame(array, columns=['year', 'population', 'countryLabel'])
dataframe = dataframe.astype(dtype= {"year" : "int64", "population" : "<U200", "countryLabel" : "<U200"})

grouped = dataframe.groupby('countryLabel').agg('last')

print(grouped)
# Out:
#                      year population
# countryLabel
# Afghanistan          2013   31822848
# Albania              2014    3020209
# Algeria              2014   38813722
# Andorra              2016     78.264
# Angola               2013   21471618
# Antigua and Barbuda  2013      89985
# Argentina            2015   43417000
# Armenia              2013    2976566
# Australia            2017   24511800
# Austria              2014    8572895
# Azerbaijan           2013    9416801
# Bahrain              2013    1332171
# Bangladesh           2013  156594962
# Barbados             2013     284644
# Belarus              2017    9504700
# Belgium              2014   11150516
# Belize               2016     366954
# Benin                2013   10323474
# Bhutan               2013     753947
# Bolivia              2000    8495271

# %%
from pandas.io.json import json_normalize
import pandas as pd
import json

jsondata = json.load(open('countrie.json'))
array = []

for data in jsondata:
    array.append([data['year'], data['population'], data['countryLabel']])
dataframe = pd.DataFrame(array, columns=['year', 'population', 'countryLabel'])
dataframe = dataframe.astype(dtype= {"year" : "int64", "population" : "int64", "countryLabel" : "<U200"})

grouped = dataframe.groupby('countryLabel').agg('last')

print(grouped)
# Out:
#                      year  population
# countryLabel
# Afghanistan          2013    31822848
# Albania              2014     3020209
# Algeria              2014    38813722
# Andorra              2016       78264
# Angola               2013    21471618
# Antigua and Barbuda  2013       89985
# Argentina            2015    43417000
# Armenia              2013     2976566
# Australia            2017    24511800
# Austria              2014     8572895
# Azerbaijan           2013     9416801
# Bahrain              2013     1332171
# Bangladesh           2013   156594962
# Barbados             2013      284644
# Belarus              2017     9504700
# Belgium              2014    11150516
# Belize               2016      366954
# Benin                2013    10323474
# Bhutan               2013      753947
# Bolivia              2000     8495271

# %%
grouped = grouped.sort_values('population')
print(grouped)
# Out:
#                      year  population
# countryLabel
# Andorra              2016       78264
# Antigua and Barbuda  2013       89985
# Barbados             2013      284644
# Belize               2016      366954
# Bhutan               2013      753947
# Bahrain              2013     1332171
# Armenia              2013     2976566
# Albania              2014     3020209
# Bolivia              2000     8495271
# Austria              2014     8572895
# Azerbaijan           2013     9416801
# Belarus              2017     9504700
# Benin                2013    10323474
# Belgium              2014    11150516
# Angola               2013    21471618
# Australia            2017    24511800
# Afghanistan          2013    31822848
# Algeria              2014    38813722
# Argentina            2015    43417000
# Bangladesh           2013   156594962

# %%
grouped.tail(1)
# Out:
#               year  population
# countryLabel
# Bangladesh    2013   156594962

# %%
grouped.head(1)
# Out:
#               year  population
# countryLabel
# Andorra       2016       78264
